# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

data = pd.read_csv(r"F:\GUVI\Project\Car Dekho\Codes\Cleaned Data\Cleaned_Full_cars_data.csv", index_col=0)

# %%
data.columns
# Out:
# Index(['Body type', 'Kilometers driven', 'Transmission type',
#        'Number of Owners', 'Car model', 'Year of manufacture', 'price',
#        'Fuel Type', 'Insurance Validity', 'Seats', 'Engine', 'Mileage',
#        'Color', 'Turbo Charger', 'Super Charger', 'Steering Type', 'Top Speed',
#        'No of doors', 'Cargo Volumn', 'City'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8369 entries, 0 to 8368
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Body type            8365 non-null   object
#  1   Kilometers driven    8369 non-null   int64
#  2   Transmission type    8369 non-null   object
#  3   Number of Owners     8369 non-null   int64
#  4   Car model            8369 non-null   object
#  5   Year of manufacture  8369 non-null   int64
#  6   price                8369 non-null   float64
#  7   Fuel Type            8369 non-null   object
#  8   Insurance Validity   8365 non-null   object
#  9   Seats                8363 non-null   float64
#  10  Engine               8365 non-null   float64
#  11  Mileage              8082 non-null   float64
#  12  Color                8366 non-null   object
#  13  Turbo Charger        7329 non-null   object
#  14  Super Charger        6407 non-null   object
#  15  Steering Type        8114 non-null   object
#  16  Top Speed            4582 non-null   float64
#  17  No of doors          8358 non-null   float64
#  18  Cargo Volumn         6776 non-null   float64
#  19  City                 8369 non-null   object
# dtypes: float64(7), int64(3), object(10)
# memory usage: 1.3+ MB

# %%
data.isnull().sum()
# Out:
# Body type                 4
# Kilometers driven         0
# Transmission type         0
# Number of Owners          0
# Car model                 0
# Year of manufacture       0
# price                     0
# Fuel Type                 0
# Insurance Validity        4
# Seats                     6
# Engine                    4
# Mileage                 287
# Color                     3
# Turbo Charger          1040
# Super Charger          1962
# Steering Type           255
# Top Speed              3787
# No of doors              11
# Cargo Volumn           1593
# City                      0
# dtype: int64

# %%
data['Body type'].mode()[0]
# Out:
# 'Hatchback'

# %%
data['Body type'].fillna(data['Body type'].mode()[0], inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\3960989014.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Body type'].fillna(data['Body type'].mode()[0], inplace=True)

# %%
data['Insurance Validity'].value_counts()
# Out:
# Insurance Validity
# Third Party insurance     4055
# Comprehensive             3150
# Third Party                630
# Zero Dep                   303
# Not Available              223
# First Party insurance        3
# Second Party insurance       1
# Name: count, dtype: int64

# %%
data['Insurance Validity'].mode()[0]
# Out:
# 'Third Party insurance'

# %%
data['Insurance Validity'].fillna(data['Insurance Validity'].mode()[0], inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\1787181864.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Insurance Validity'].fillna(data['Insurance Validity'].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# Body type                 0
# Kilometers driven         0
# Transmission type         0
# Number of Owners          0
# Car model                 0
# Year of manufacture       0
# price                     0
# Fuel Type                 0
# Insurance Validity        0
# Seats                     6
# Engine                    4
# Mileage                 287
# Color                     3
# Turbo Charger          1040
# Super Charger          1962
# Steering Type           255
# Top Speed              3787
# No of doors              11
# Cargo Volumn           1593
# City                      0
# dtype: int64

# %%
data['Seats'].median()
# Out:
# 5.0

# %%
data['Seats'].fillna(data['Seats'].median(), inplace= True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\751290087.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Seats'].fillna(data['Seats'].median(), inplace= True)

# %%
data['Engine'].median()
# Out:
# 1248.0

# %%
data['Engine'].fillna(data['Engine'].median(), inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\1674788604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Engine'].fillna(data['Engine'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Body type                 0
# Kilometers driven         0
# Transmission type         0
# Number of Owners          0
# Car model                 0
# Year of manufacture       0
# price                     0
# Fuel Type                 0
# Insurance Validity        0
# Seats                     0
# Engine                    0
# Mileage                 287
# Color                     3
# Turbo Charger          1040
# Super Charger          1962
# Steering Type           255
# Top Speed              3787
# No of doors              11
# Cargo Volumn           1593
# City                      0
# dtype: int64

# %%
data['Mileage'].mean()
# Out:
# 19.255853130413264

# %%
data['Mileage'].fillna(data['Mileage'].mean(), inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\3272080093.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Mileage'].fillna(data['Mileage'].mean(), inplace=True)

# %%
data['Color'].value_counts()
# Out:
# Color
# Others             2168
# White              1655
# Silver             1281
# Red                 798
# Blue                605
#                    ...
# Cirrus White          1
# Passion Red           1
# Hip Hop Black         1
# Cherry                1
# Out Back Bronze       1
# Name: count, Length: 153, dtype: int64

# %%
data['Color'].fillna(data['Color'].mode()[0], inplace= True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\1895152529.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Color'].fillna(data['Color'].mode()[0], inplace= True)

# %%
data['Turbo Charger'].fillna(data['Turbo Charger'].mode()[0], inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\187063961.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Turbo Charger'].fillna(data['Turbo Charger'].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# Body type                 0
# Kilometers driven         0
# Transmission type         0
# Number of Owners          0
# Car model                 0
# Year of manufacture       0
# price                     0
# Fuel Type                 0
# Insurance Validity        0
# Seats                     0
# Engine                    0
# Mileage                   0
# Color                     0
# Turbo Charger             0
# Super Charger          1962
# Steering Type           255
# Top Speed              3787
# No of doors              11
# Cargo Volumn           1593
# City                      0
# dtype: int64

# %%
data['Super Charger'].mode()[0]
# Out:
# 'No'

# %%
data['Super Charger'].fillna(data['Super Charger'].mode()[0], inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\1950576790.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Super Charger'].fillna(data['Super Charger'].mode()[0], inplace=True)

# %%
data['Steering Type'].mode()[0]
# Out:
# 'Power'

# %%
data['Steering Type'].fillna(data['Steering Type'].mode()[0], inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\695079919.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Steering Type'].fillna(data['Steering Type'].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# Body type                 0
# Kilometers driven         0
# Transmission type         0
# Number of Owners          0
# Car model                 0
# Year of manufacture       0
# price                     0
# Fuel Type                 0
# Insurance Validity        0
# Seats                     0
# Engine                    0
# Mileage                   0
# Color                     0
# Turbo Charger             0
# Super Charger             0
# Steering Type             0
# Top Speed              3787
# No of doors              11
# Cargo Volumn           1593
# City                      0
# dtype: int64

# %%
data['Top Speed'].median()
# Out:
# 170.0

# %%
data['Top Speed'].fillna(data['Top Speed'].median(), inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\4232917131.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Top Speed'].fillna(data['Top Speed'].median(), inplace=True)

# %%
data['No of doors'].median()
# Out:
# 5.0

# %%
data['No of doors'].fillna(data['No of doors'].median(), inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\1903273974.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['No of doors'].fillna(data['No of doors'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# Body type                 0
# Kilometers driven         0
# Transmission type         0
# Number of Owners          0
# Car model                 0
# Year of manufacture       0
# price                     0
# Fuel Type                 0
# Insurance Validity        0
# Seats                     0
# Engine                    0
# Mileage                   0
# Color                     0
# Turbo Charger             0
# Super Charger             0
# Steering Type             0
# Top Speed                 0
# No of doors               0
# Cargo Volumn           1593
# City                      0
# dtype: int64

# %%
data['Cargo Volumn'].mean()
# Out:
# 9544.285566706021

# %%
data['Cargo Volumn'].fillna(data['Cargo Volumn'].mean(), inplace= True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_2424\3885226953.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Cargo Volumn'].fillna(data['Cargo Volumn'].mean(), inplace= True)

# %%
data.isnull().sum()
# Out:
# Body type              0
# Kilometers driven      0
# Transmission type      0
# Number of Owners       0
# Car model              0
# Year of manufacture    0
# price                  0
# Fuel Type              0
# Insurance Validity     0
# Seats                  0
# Engine                 0
# Mileage                0
# Color                  0
# Turbo Charger          0
# Super Charger          0
# Steering Type          0
# Top Speed              0
# No of doors            0
# Cargo Volumn           0
# City                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8369 entries, 0 to 8368
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Body type            8369 non-null   object
#  1   Kilometers driven    8369 non-null   int64
#  2   Transmission type    8369 non-null   object
#  3   Number of Owners     8369 non-null   int64
#  4   Car model            8369 non-null   object
#  5   Year of manufacture  8369 non-null   int64
#  6   price                8369 non-null   float64
#  7   Fuel Type            8369 non-null   object
#  8   Insurance Validity   8369 non-null   object
#  9   Seats                8369 non-null   float64
#  10  Engine               8369 non-null   float64
#  11  Mileage              8369 non-null   float64
#  12  Color                8369 non-null   object
#  13  Turbo Charger        8369 non-null   object
#  14  Super Charger        8369 non-null   object
#  15  Steering Type        8369 non-null   object
#  16  Top Speed            8369 non-null   float64
#  17  No of doors          8369 non-null   float64
#  18  Cargo Volumn         8369 non-null   float64
#  19  City                 8369 non-null   object
# dtypes: float64(7), int64(3), object(10)
# memory usage: 1.3+ MB

# %%
data['No of doors'] = data['No of doors'].astype(int)

# %%
data['Cargo Volumn'] = data['Cargo Volumn'].astype(int)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data = data)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data = data, x='Kilometers driven')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data = data, x='price')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data = data, x='Cargo Volumn')
plt.show()

# %%
data['Cargo Volumn'].max()
# Out:
# 3851405

# %%
data['Cargo Volumn'].min()
# Out:
# 29

# %%
data['Cargo Volumn'].mean()
# Out:
# 9544.231210419404

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8369 entries, 0 to 8368
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Body type            8369 non-null   object
#  1   Kilometers driven    8369 non-null   int64
#  2   Transmission type    8369 non-null   object
#  3   Number of Owners     8369 non-null   int64
#  4   Car model            8369 non-null   object
#  5   Year of manufacture  8369 non-null   int64
#  6   price                8369 non-null   float64
#  7   Fuel Type            8369 non-null   object
#  8   Insurance Validity   8369 non-null   object
#  9   Seats                8369 non-null   float64
#  10  Engine               8369 non-null   float64
#  11  Mileage              8369 non-null   float64
#  12  Color                8369 non-null   object
#  13  Turbo Charger        8369 non-null   object
#  14  Super Charger        8369 non-null   object
#  15  Steering Type        8369 non-null   object
#  16  Top Speed            8369 non-null   float64
#  17  No of doors          8369 non-null   int32
#  18  Cargo Volumn         8369 non-null   int32
#  19  City                 8369 non-null   object
# dtypes: float64(5), int32(2), int64(3), object(10)
# memory usage: 1.3+ MB

# %%
data1 = data.drop(["Body type",'Transmission type','Car model','Fuel Type','Insurance Validity','Color', 'Turbo Charger', 'Super Charger',
                   'Steering Type','City'], axis= 1)

# %%
corr = data1.corr()

# %%
plt.figure(figsize=(16,5))
sns.heatmap(corr, fmt='.2f', annot=True, cmap='coolwarm')
plt.show()

# %%
data.to_csv("Final_data.csv")
