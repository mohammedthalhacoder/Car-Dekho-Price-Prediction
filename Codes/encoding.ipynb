# %%
import pandas as pd
from scipy.stats import boxcox
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv(r"F:\GUVI\Project\Car Dekho\Codes\Cleaned Data\Final_data.csv", index_col=0)

# %%
data.isnull().sum()
# Out:
# Body type              0
# Kilometers driven      0
# Transmission type      0
# Number of Owners       0
# Car model              0
# Year of manufacture    0
# price                  0
# Fuel Type              0
# Insurance Validity     0
# Seats                  0
# Engine                 0
# Mileage                0
# Color                  0
# Turbo Charger          0
# Super Charger          0
# Steering Type          0
# Top Speed              0
# No of doors            0
# Cargo Volumn           0
# City                   0
# dtype: int64

# %%
data.shape
# Out:
# (8369, 20)

# %%
data['Top Speed'] = data['Top Speed'].astype(int)

# %%
data['Seats'] = data['Seats'].astype(int)

# %%
data.head()
# Out:
#    Body type  Kilometers driven Transmission type  Number of Owners  \
# 0  Hatchback             120000            Manual                 3
# 1        SUV              32706            Manual                 2
# 2  Hatchback              11949            Manual                 1
# 3      Sedan              17794            Manual                 1
# 4        SUV              60000            Manual                 1
#
#             Car model  Year of manufacture     price Fuel Type  \
# 0      Maruti Celerio                 2015  400000.0    Petrol
# 1       Ford Ecosport                 2018  811000.0    Petrol
# 2          Tata Tiago                 2018  585000.0    Petrol
# 3       Hyundai Xcent                 2014  462000.0    Petrol
# 4  Maruti SX4 S Cross                 2015  790000.0    Diesel
#
#       Insurance Validity  Seats  Engine  Mileage   Color Turbo Charger  \
# 0  Third Party insurance      5   998.0    23.10   White            No
# 1          Comprehensive      5  1497.0    17.00   White            No
# 2          Comprehensive      5  1199.0    23.84     Red            No
# 3          Comprehensive      5  1197.0    19.10  Others            No
# 4  Third Party insurance      5  1248.0    23.65    Gray           Yes
#
#   Super Charger Steering Type  Top Speed  No of doors  Cargo Volumn       City
# 0            No         Power        150            5           235  bangalore
# 1            No         Power        170            4           352  bangalore
# 2            No         Power        150            5           242  bangalore
# 3            No         Power        172            4           407  bangalore
# 4            No         Power        190            5           353  bangalore

# %%
# Outliers Control
data['Cargo Volumn'].max()
# Out:
# 3851405

# %%
# Boxcox method
value, _ = boxcox(data['Cargo Volumn'])

# %%
data['Cargo Volumn'] = value

# %%
sns.boxplot(data=data['Cargo Volumn'])
plt.show()

# %%
# sqrt method

np.sqrt(data['Cargo Volumn'])
# Out:
# 0       1.275174
# 1       1.280771
# 2       1.275628
# 3       1.282473
# 4       1.280806
#           ...
# 8364    1.279282
# 8365    1.270350
# 8366    1.284128
# 8367    1.275240
# 8368    1.282555
# Name: Cargo Volumn, Length: 8369, dtype: float64

# %%
sns.boxplot(data=np.sqrt(data['Cargo Volumn']))
plt.show()

# %%
# log2 method
np.log2(data['Cargo Volumn'])
# Out:
# 0       0.701387
# 1       0.714025
# 2       0.702415
# 3       0.717856
# 4       0.714103
#           ...
# 8364    0.710668
# 8365    0.690451
# 8366    0.721578
# 8367    0.701537
# 8368    0.718041
# Name: Cargo Volumn, Length: 8369, dtype: float64

# %%
sns.boxplot(data=np.log2(data['Cargo Volumn']))
plt.show()

# %%
# log10 method

sns.boxplot(data=np.log10(data['Cargo Volumn']))
plt.show()

# %%
data['Inverse_transform'] = data['Cargo Volumn'].apply(lambda x: 1/x)

# %%
sns.boxplot(data=data['Inverse_transform'])
plt.show()

# %%
data.head()
# Out:
#    Body type  Kilometers driven Transmission type  Number of Owners  \
# 0  Hatchback             120000            Manual                 3
# 1        SUV              32706            Manual                 2
# 2  Hatchback              11949            Manual                 1
# 3      Sedan              17794            Manual                 1
# 4        SUV              60000            Manual                 1
#
#             Car model  Year of manufacture     price Fuel Type  \
# 0      Maruti Celerio                 2015  400000.0    Petrol
# 1       Ford Ecosport                 2018  811000.0    Petrol
# 2          Tata Tiago                 2018  585000.0    Petrol
# 3       Hyundai Xcent                 2014  462000.0    Petrol
# 4  Maruti SX4 S Cross                 2015  790000.0    Diesel
#
#       Insurance Validity  Seats  ...  Mileage   Color Turbo Charger  \
# 0  Third Party insurance      5  ...    23.10   White            No
# 1          Comprehensive      5  ...    17.00   White            No
# 2          Comprehensive      5  ...    23.84     Red            No
# 3          Comprehensive      5  ...    19.10  Others            No
# 4  Third Party insurance      5  ...    23.65    Gray           Yes
#
#   Super Charger Steering Type Top Speed  No of doors  Cargo Volumn       City  \
# 0            No         Power       150            5      1.626068  bangalore
# 1            No         Power       170            4      1.640374  bangalore
# 2            No         Power       150            5      1.627226  bangalore
# 3            No         Power       172            4      1.644736  bangalore
# 4            No         Power       190            5      1.640463  bangalore
#
#   Inverse_transform
# 0          0.614981
# 1          0.609617
# 2          0.614543
# 3          0.608000
# 4          0.609584
#
# [5 rows x 21 columns]

# %%
# droping the columns outliers
# "Cargo Volumn", "Inverse_transform"

# %%
data.drop(['Cargo Volumn', 'Inverse_transform'], axis=1, inplace=True)

# %%
data
# Out:
#       Body type  Kilometers driven Transmission type  Number of Owners  \
# 0     Hatchback             120000            Manual                 3
# 1           SUV              32706            Manual                 2
# 2     Hatchback              11949            Manual                 1
# 3         Sedan              17794            Manual                 1
# 4           SUV              60000            Manual                 1
# ...         ...                ...               ...               ...
# 8364  Hatchback              10000            Manual                 1
# 8365  Hatchback             120000            Manual                 1
# 8366      Sedan              50000         Automatic                 3
# 8367  Hatchback              40000            Manual                 1
# 8368        SUV             120000            Manual                 2
#
#                   Car model  Year of manufacture     price Fuel Type  \
# 0            Maruti Celerio                 2015  400000.0    Petrol
# 1             Ford Ecosport                 2018  811000.0    Petrol
# 2                Tata Tiago                 2018  585000.0    Petrol
# 3             Hyundai Xcent                 2014  462000.0    Petrol
# 4        Maruti SX4 S Cross                 2015  790000.0    Diesel
# ...                     ...                  ...       ...       ...
# 8364         Maruti Celerio                 2022  510000.0    Petrol
# 8365        Maruti Alto 800                 2014  180000.0    Petrol
# 8366  Mercedes-Benz C-Class                 2011  550000.0    Petrol
# 8367            Maruti Ritz                 2012  140000.0    Petrol
# 8368         Renault Duster                 2017  500000.0    Diesel
#
#          Insurance Validity  Seats  Engine  Mileage   Color Turbo Charger  \
# 0     Third Party insurance      5   998.0    23.10   White            No
# 1             Comprehensive      5  1497.0    17.00   White            No
# 2             Comprehensive      5  1199.0    23.84     Red            No
# 3             Comprehensive      5  1197.0    19.10  Others            No
# 4     Third Party insurance      5  1248.0    23.65    Gray           Yes
# ...                     ...    ...     ...      ...     ...           ...
# 8364  Third Party insurance      5   998.0    25.24  Others            No
# 8365  Third Party insurance      5   796.0    22.74  Others            No
# 8366  Third Party insurance      5  1796.0    11.74  Others            No
# 8367  Third Party insurance      5  1197.0    18.50  Others            No
# 8368  Third Party insurance      5  1461.0    19.72  Others           Yes
#
#      Super Charger Steering Type  Top Speed  No of doors       City
# 0               No         Power        150            5  bangalore
# 1               No         Power        170            4  bangalore
# 2               No         Power        150            5  bangalore
# 3               No         Power        172            4  bangalore
# 4               No         Power        190            5  bangalore
# ...            ...           ...        ...          ...        ...
# 8364            No      Electric        170            5    kolkata
# 8365            No         Power        140            5    kolkata
# 8366            No         Power        230            4    kolkata
# 8367            No         Power        156            5    kolkata
# 8368            No         Power        168            5    kolkata
#
# [8369 rows x 19 columns]

# %%
# Encoding the Categorical data or columns

# %%
data.select_dtypes(include='object')
# Out:
#       Body type Transmission type              Car model Fuel Type  \
# 0     Hatchback            Manual         Maruti Celerio    Petrol
# 1           SUV            Manual          Ford Ecosport    Petrol
# 2     Hatchback            Manual             Tata Tiago    Petrol
# 3         Sedan            Manual          Hyundai Xcent    Petrol
# 4           SUV            Manual     Maruti SX4 S Cross    Diesel
# ...         ...               ...                    ...       ...
# 8364  Hatchback            Manual         Maruti Celerio    Petrol
# 8365  Hatchback            Manual        Maruti Alto 800    Petrol
# 8366      Sedan         Automatic  Mercedes-Benz C-Class    Petrol
# 8367  Hatchback            Manual            Maruti Ritz    Petrol
# 8368        SUV            Manual         Renault Duster    Diesel
#
#          Insurance Validity   Color Turbo Charger Super Charger Steering Type  \
# 0     Third Party insurance   White            No            No         Power
# 1             Comprehensive   White            No            No         Power
# 2             Comprehensive     Red            No            No         Power
# 3             Comprehensive  Others            No            No         Power
# 4     Third Party insurance    Gray           Yes            No         Power
# ...                     ...     ...           ...           ...           ...
# 8364  Third Party insurance  Others            No            No      Electric
# 8365  Third Party insurance  Others            No            No         Power
# 8366  Third Party insurance  Others            No            No         Power
# 8367  Third Party insurance  Others            No            No         Power
# 8368  Third Party insurance  Others           Yes            No         Power
#
#            City
# 0     bangalore
# 1     bangalore
# 2     bangalore
# 3     bangalore
# 4     bangalore
# ...         ...
# 8364    kolkata
# 8365    kolkata
# 8366    kolkata
# 8367    kolkata
# 8368    kolkata
#
# [8369 rows x 10 columns]

# %%
le = LabelEncoder()
for i in data.select_dtypes(include='object'):
    data[i] = le.fit_transform(data[i])

# %%
data
# Out:
#       Body type  Kilometers driven  Transmission type  Number of Owners  \
# 0             2             120000                  1                 3
# 1             7              32706                  1                 2
# 2             2              11949                  1                 1
# 3             8              17794                  1                 1
# 4             7              60000                  1                 1
# ...         ...                ...                ...               ...
# 8364          2              10000                  1                 1
# 8365          2             120000                  1                 1
# 8366          8              50000                  0                 3
# 8367          2              40000                  1                 1
# 8368          7             120000                  1                 2
#
#       Car model  Year of manufacture     price  Fuel Type  Insurance Validity  \
# 0           160                 2015  400000.0          4                   5
# 1            50                 2018  811000.0          4                   0
# 2           273                 2018  585000.0          4                   0
# 3            87                 2014  462000.0          4                   0
# 4           178                 2015  790000.0          1                   5
# ...         ...                  ...       ...        ...                 ...
# 8364        160                 2022  510000.0          4                   5
# 8365        155                 2014  180000.0          4                   5
# 8366        197                 2011  550000.0          4                   5
# 8367        175                 2012  140000.0          4                   5
# 8368        236                 2017  500000.0          1                   5
#
#       Seats  Engine  Mileage  Color  Turbo Charger  Super Charger  \
# 0         5   998.0    23.10    138              0              0
# 1         5  1497.0    17.00    138              0              0
# 2         5  1199.0    23.84    110              0              0
# 3         5  1197.0    19.10     86              0              0
# 4         5  1248.0    23.65     55              3              0
# ...     ...     ...      ...    ...            ...            ...
# 8364      5   998.0    25.24     86              0              0
# 8365      5   796.0    22.74     86              0              0
# 8366      5  1796.0    11.74     86              0              0
# 8367      5  1197.0    18.50     86              0              0
# 8368      5  1461.0    19.72     86              3              0
#
#       Steering Type  Top Speed  No of doors  City
# 0                 4        150            5     0
# 1                 4        170            4     0
# 2                 4        150            5     0
# 3                 4        172            4     0
# 4                 4        190            5     0
# ...             ...        ...          ...   ...
# 8364              1        170            5     5
# 8365              4        140            5     5
# 8366              4        230            4     5
# 8367              4        156            5     5
# 8368              4        168            5     5
#
# [8369 rows x 19 columns]

# %%
data_corr = data.corr()

# %%
plt.figure(figsize=(16,7))
sns.heatmap(data=data_corr,fmt=".2f", annot=True, cmap="coolwarm")
plt.show()

# %%
sns.histplot(data=data, x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
data.to_csv(r"F:\GUVI\Project\Car Dekho\Codes\model_data\encoded_data.csv")
